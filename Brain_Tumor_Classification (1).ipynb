# %% [markdown]
# # Import Statements

# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # One Hot Encoding the Target Classes

# %%
# 0 - Tumor
# 1 - Normal
encoder = OneHotEncoder()
encoder.fit([[0], [1]])
# Out:
# OneHotEncoder()

# %% [markdown]
# # Creating 3 Important Lists --
# 1. data list for storing image data in numpy array form
# 2. paths list for storing paths of all images
# 3. result list for storing one hot encoded form of target class whether normal or tumor

# %%
data = []
paths = []
result = []

for r, d, f in os.walk(r'D:/brain tumorr/archive (6)/brain_tumor_dataset/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
paths = []
for r, d, f in os.walk(r"D:/brain tumorr/archive (6)/brain_tumor_dataset/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %% [markdown]
# # Splitting the Data into Training & Testing

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %% [markdown]
# # Model Building

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      416
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4128
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        8256
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        16448
#
#  batch_normalization_1 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 64)        0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 512)               33554944
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 33,585,602
# Trainable params: 33,585,410
# Non-trainable params: 192
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (111, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 13s 2s/step - loss: 17.9979 - val_loss: 26.8840
# Epoch 2/30
# 3/3 [==============================] - 5s 2s/step - loss: 14.6179 - val_loss: 52.0781
# Epoch 3/30
# 3/3 [==============================] - 5s 2s/step - loss: 4.0215 - val_loss: 8.7736
# Epoch 4/30
# 3/3 [==============================] - 5s 2s/step - loss: 4.2287 - val_loss: 6.2801
# Epoch 5/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.9928 - val_loss: 12.3584
# Epoch 6/30
# 3/3 [==============================] - 5s 2s/step - loss: 1.9451 - val_loss: 11.0654
# Epoch 7/30
# 3/3 [==============================] - 5s 2s/step - loss: 1.1301 - val_loss: 5.0486
# Epoch 8/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.4456 - val_loss: 5.4551
# Epoch 9/30
# 3/3 [==============================] - 5s 2s/step - loss: 1.0648 - val_loss: 6.8476
# Epoch 10/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.7687 - val_loss: 4.7964
# Epoch 11/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.2729 - val_loss: 3.2214
# Epoch 12/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1246 - val_loss: 3.7551
# Epoch 13/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0972 - val_loss: 4.6407
# Epoch 14/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1394 - val_loss: 5.1027
# Epoch 15/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1382 - val_loss: 4.8851
# Epoch 16/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1266 - val_loss: 4.3564
# Epoch 17/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1133 - val_loss: 4.0157
# Epoch 18/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0101 - val_loss: 3.9437
# Epoch 19/30
# 3/3 [==============================] - 5s 2s/step - loss: 1.4239e-05 - val_loss: 3.9139
# Epoch 20/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0657 - val_loss: 3.8522
# Epoch 21/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0367 - val_loss: 3.7686
# Epoch 22/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0020 - val_loss: 3.7113
# Epoch 23/30
# 3/3 [==============================] - 5s 2s/step - loss: 1.0327e-05 - val_loss: 3.6818
# Epoch 24/30
# 3/3 [==============================] - 5s 2s/step - loss: 2.7586e-06 - val_loss: 3.6733
# Epoch 25/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0883 - val_loss: 3.6592
# Epoch 26/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0288 - val_loss: 3.6089
# Epoch 27/30
# 3/3 [==============================] - 5s 2s/step - loss: 1.0321e-05 - val_loss: 3.5935
# Epoch 28/30
# 3/3 [==============================] - 5s 2s/step - loss: 8.9611e-06 - val_loss: 3.5880
# Epoch 29/30
# 3/3 [==============================] - 5s 2s/step - loss: 1.4200e-04 - val_loss: 3.5856
# Epoch 30/30
# 3/3 [==============================] - 5s 2s/step - loss: 1.3948e-04 - val_loss: 3.5872

# %% [markdown]
# # Plotting Losses

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# #  Checking the Model

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"D:/brain tumorr/archive (6)/brain_tumor_dataset/no/N17.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 100.0% Confidence This Is No, Its not a tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"D:/brain tumorr/archive (6)/brain_tumor_dataset/yes/Y3.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
# Out:
# 99.9951958656311% Confidence This Is A Its a Tumor
